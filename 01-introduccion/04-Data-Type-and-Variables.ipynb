# %% [markdown]
# ## Tipos de Datos
#
# * Númericos
# * Booleans
# * Variables
#
# ### Numericos
#
# * int --> 1, 2, 3, 4
# * floats (punto flotante) --> 1.0, 3.14, 100.5
# * complejos --> 2 + 4i , donde 2 es la parte real y 4 es la parte imaginaria

# %%
x = 7
type(x)
# Out:
# int

# %%
y = 3.14
type(y)
# Out:
# float

# %%
z = complex(x, y)
type(z)
# Out:
# complex

# %%
z.real
# Out:
# 7.0

# %%
z.imag
# Out:
# 3.14

# %%
type(x)
# Out:
# int

# %% [markdown]
# ### Boolean
#
#
# *   True or False

# %%
type(3 == 4)
# Out:
# bool

# %% [markdown]
# ## Variables

# %%
# Una variable es la forma de asignar un valor a una entidad
course = "Python for padawans"

# Para luego poder interactuar con ella
course
# Out:
# 'Python for padawans'

# %%
print(course)
# Out:
# Python for padawans

# %%
# algunas reglas: no deben empezar por numeros o caracteres especiales
other_course = "Java for padawans"

# %%
# Al programar, pueden decidir utilizar como estandar snake_case
snake_case_variable = "Esto es una variable en snake case"
snake_case_variable
# Out:
# 'Esto es una variable en snake case'

# %%
# O pueden decidir utilizar, camelCase
camelCaseVariable = 'Esto es camel case standard'

camelCaseVariable
# Out:
# 'Esto es camel case standard'
