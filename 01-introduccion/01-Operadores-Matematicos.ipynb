# %% [markdown]
# ## Operadores Matematicos
#
#
# * Suma
# * Resta
# * Multiplicación
# * División
# * División Entera
# * Resto
# * Potencia

# %%
# Suma en Python
89 + 11
# Out:
# 100

# %%
# Resta en Python
100 - 49
# Out:
# 51

# %%
# Multiplicacion
10 * 5
# Out:
# 50

# %%
# Division
19 / 3
# Out:
# 6.333333333333333

# %%
# Division Entera
19 // 3
# Out:
# 6

# %%
# Modulo O Resto de la division
19 % 3
# Out:
# 1

# %%
# Exponenciacion
2 ** 3
# Out:
# 8

# %%
# Orden de los Operadores
# El resultado no es 27
4 + 5 * 3  - 4 / 2
# Out:
# 17.0

# %%
# El resultado no es 17
(4 + 5) * ( 3 - 4 ) / 2
# Out:
# -4.5

# %% [markdown]
# ## La libreria Math

# %%
# https://docs.python.org/3/library/math.html
import math

# %%
# La libreria Math de python tiene constantes numericas
math.pi
# Out:
# 3.141592653589793

# %%
# Tambien tiene un sin fin de funciones, como las funciones trigonometricas (seno, coseno, tangente, entre otros) u otros como la raiz cuadrada
math.sqrt(64)
# Out:
# 8.0

# %% [markdown]
# ## Ejercicios

# %%
2 ** 3 ** 2
# Out:
# 512

# %%
(2 ** 3) ** 2
# Out:
# 64

# %%
2 ** (3 ** 2)
# Out:
# 512
