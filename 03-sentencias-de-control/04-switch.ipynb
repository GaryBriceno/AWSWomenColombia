# %% [markdown]
# https://www.clubdetecnologia.net/blog/2017/python-como-se-implementa-una-sentencia-switch-case/

# %%
mes = input("Ingrese el mes")
# Out:
# Ingrese el mesEnero

# %%
if mes == "Enero":
  print("Enero")
elif mes == "Febrero":
  print("Febrero")
elif mes == "Marzo":
  print("Marzo")
elif mes == "Abril":
  print("Abril")
elif mes == "Mayo":
  print("Mayo")
elif mes == "Junio":
  print("Junio")
else:
  mes("El mes ingresado es diferente")
# Out:
# Enero
