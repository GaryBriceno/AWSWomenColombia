# %% [markdown]
# - Youtube:
#   - https://www.youtube.com/channel/UCKKTmI4UnLOZSH1xa46afWA
# - Mi blog:
#  - https://www.clubdetecnologia.net/blog/

# %%
# if <True>:
#   acciones_verdadero
# else
#   acciones_falso

# %%
# Si tiene carnet de vacunacion, ingresa
# Si no tiene, no ingresa

carnet_vacunacion = False

if carnet_vacunacion:
  print("Bienvenido al Restaurante.")
else:
  print("Disculpe, de momento no puede ingresar.")
# Out:
# Disculpe, de momento no puede ingresar

# %%
# Si tiene el carnet digital, tambien ingresa
carnet_vacunacion_digital = True

if carnet_vacunacion:
  print("Bienvenido al Restaurante.")
elif carnet_vacunacion_digital:
  print("Bienvenido, carnet digital verificado.")
else:
  print("Disculpe, de momento no puede ingresar.")
# Out:
# Bienvenido, carnet digital verificado.

# %%
edad = input('Ingrese su edad: ')
# Out:
# Ingrese su edad: 18

# %%
edad = int(edad)

if edad >= 18:
  print("Puede ingresar a la disco")
else:
  print("No puede ingresar")
# Out:
# Puede ingresar a la disco

# %%
if None:
  print("Ingreso a None")

# %%
if not None:
  print("Ingreso a None")
# Out:
# Ingreso a None

# %%
if 0:
  print("")
else:
  print("Cuando es 0 es como si fuera falso")
# Out:
# Cuando es 0 es como si fuera falso

# %% [markdown]
# ### Ejercicio:
#
# Generar un programa que reciba dos valores, y luego nos de la suma, resta, multiplicacion y division de ellos.
